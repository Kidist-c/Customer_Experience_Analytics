# %% [markdown]
# ### Store Cleaned Data in PostgreSQL
# * Insert cleaned review data using Python

# %%
from dotenv import  load_dotenv
import psycopg2
import os

# %%
load_dotenv()
# Out:
# True

# %%
import pandas as pd
df=pd.read_csv("../data/processed/bank_reviews_with_themes.csv")
df.head(5)
# Out:
#                               review_id  \
# 0  5112423d-e618-44ba-ba49-62677cb76cd6
# 1  bcb34681-1dd4-4781-b400-4393bb10b1d9
# 2  c69f051a-00f8-4144-8423-b7ebcd328d2d
# 3  f8002d06-b5c5-4ed1-9d51-a9a379304cf8
# 4  81000db5-aa51-467e-826c-fc96160e96a8
#
#                                               review  rating        date  \
# 0  This application is very important and advanta...       5  2025-11-28
# 1                          why didn't work this app?       1  2025-11-28
# 2      The app makes our life easier. Thank you CBE!       5  2025-11-28
# 3       the most advanced app. but how to stay safe?       5  2025-11-27
# 4                                   Good application       4  2025-11-27
#
#                           bank             source sentiment_label  \
# 0  Commercial Bank of Ethiopia  Google Play Store        POSITIVE
# 1  Commercial Bank of Ethiopia  Google Play Store        NEGATIVE
# 2  Commercial Bank of Ethiopia  Google Play Store        POSITIVE
# 3  Commercial Bank of Ethiopia  Google Play Store        NEGATIVE
# 4  Commercial Bank of Ethiopia  Google Play Store        POSITIVE
#
#    sentiment_score                                       clean_review  topic  \
# 0         0.998468  this application is very important and advanta...      1
# 1         0.999132                            why didnt work this app      1
# 2         0.999696        the app makes our life easier thank you cbe      1
# 3         0.956510         the most advanced app but how to stay safe      1
# 4         0.999855                                   good application      1
#
#                              theme
# 0  General Praise / Mixed Feedback
# 1  General Praise / Mixed Feedback
# 2  General Praise / Mixed Feedback
# 3  General Praise / Mixed Feedback
# 4  General Praise / Mixed Feedback

# %% [markdown]
# #### Insert cleaned review data using psycopg2

# %%
conn=psycopg2.connect(
    host="localhost",
    database="bank_reviews",
    user="postgres",
    password=os.getenv("DB_PASSWORD")
) #create a database connection
cursor=conn.cursor() #create a cursor object
